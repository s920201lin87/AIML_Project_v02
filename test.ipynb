# %%
import pandas as pd
import numpy as np
from scipy.io import loadmat

# %%
data = loadmat('Oxford_Battery_Degradation_Dataset_1.mat')
print(data.keys())  # 查看數據的主要結構和變數名稱
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Cell1', 'Cell2', 'Cell3', 'Cell4', 'Cell5', 'Cell6', 'Cell7', 'Cell8'])

# %%
import os
import pandas as pd
from scipy.io import loadmat
import numpy as np

# 读入 .mat 文件
data = loadmat('Oxford_Battery_Degradation_Dataset_1.mat')

# 获取数据中的主要 keys（去掉系统保留的 keys）
keys = [key for key in data.keys() if not key.startswith('__')]
print("Keys in the dataset:", keys)

# 创建顶层数据文件夹
base_dir = "data"
os.makedirs(base_dir, exist_ok=True)

# 遍历每个 Cell (例如 Cell1, Cell2 等)
for cell_key in keys:
    print(f"Processing {cell_key}...")
    cell_data = data[cell_key]

    # 创建对应的 Cell 文件夹
    cell_dir = os.path.join(base_dir, cell_key)
    os.makedirs(cell_dir, exist_ok=True)

    # 获取 cell_data 的字段名称（例如 cyc0000, cyc0100 等）
    fields = cell_data.dtype.names
    print(f"Fields in {cell_key}:", fields)

    # 遍历每个 field (例如 cyc0000, cyc0100)
    for field in fields:
        print(f"Processing field: {field}")
        field_data = cell_data[field]

        # 创建对应的子文件夹 (e.g., data/Cell1/cyc0000/)
        field_dir = os.path.join(cell_dir, field)
        os.makedirs(field_dir, exist_ok=True)

        # 展开数据
        for i in range(field_data.size):
            element = field_data[0, i]

            # 检查子字段
            if element.dtype.names:
                sub_fields = element.dtype.names
                print(f"Sub-fields in element: {sub_fields}")

                # 遍历每个子字段 (C1ch, C1dc, OCVch, OCVdc)
                for sub_field in sub_fields:
                    print(f"Processing sub-field: {sub_field}")
                    sub_data = np.squeeze(element[sub_field])  # 提取子字段数据

                    # 初始化列表存储子字段数据
                    sub_field_data = []

                    # 进一步展开子字段的嵌套结构
                    for record in sub_data.flatten()[0].flatten():
                        # 提取时间 (t), 电压 (v), 电荷 (q), 温度 (T)
                        t = record[0].flatten()  # 时间
                        v = record[1].flatten()  # 电压
                        q = record[2].flatten()  # 电荷
                        T = record[3].flatten()  # 温度

                        # 将每组数据存储为 DataFrame 的列
                        cycle_data = pd.DataFrame({
                            "Time": t,
                            "Voltage": v,
                            "Charge": q,
                            "Temperature": T
                        })

                        # 添加到列表中
                        sub_field_data.append(cycle_data)

                    # 合并子字段数据为单个 DataFrame
                    if sub_field_data:
                        final_df = pd.concat(sub_field_data, ignore_index=True)

                        # 保存为 CSV 文件
                        file_path = os.path.join(field_dir, f"{sub_field}.csv")
                        final_df.to_csv(file_path, index=False)
                        print(f"{sub_field} data saved to '{file_path}'")
                    else:
                        print(f"No data extracted for {sub_field} in {field}")


print("Data extraction and saving complete.")
# Out:
# Keys in the dataset: ['Cell1', 'Cell2', 'Cell3', 'Cell4', 'Cell5', 'Cell6', 'Cell7', 'Cell8']
# Processing Cell1...
# Fields in Cell2: ('cyc0000', 'cyc0100', 'cyc0200', 'cyc0300', 'cyc0400', 'cyc0500', 'cyc0600', 'cyc0700', 'cyc0800', 'cyc0900', 'cyc1000', 'cyc1100', 'cyc1200', 'cyc1300', 'cyc1400', 'cyc1600', 'cyc1800', 'cyc1900', 'cyc2000', 'cyc2100', 'cyc2200', 'cyc2300', 'cyc2400', 'cyc2500', 'cyc2600', 'cyc2700', 'cyc2800', 'cyc2900', 'cyc3000', 'cyc3100', 'cyc3200', 'cyc3300', 'cyc3500', 'cyc3600', 'cyc3700', 'cyc3800', 'cyc3900', 'cyc4000', 'cyc4100', 'cyc4200', 'cyc4300', 'cyc4400', 'cyc4500', 'cyc4600', 'cyc4800', 'cyc5000', 'cyc5100', 'cyc5200', 'cyc5300', 'cyc5400', 'cyc5500', 'cyc5600', 'cyc5700', 'cyc5800', 'cyc5900', 'cyc6000', 'cyc6100', 'cyc6200', 'cyc6300', 'cyc6400', 'cyc6500', 'cyc6600', 'cyc6700', 'cyc6800', 'cyc6900', 'cyc7000', 'cyc7100', 'cyc7200', 'cyc7300', 'cyc7400', 'cyc7500', 'cyc7600', 'cyc7700')
# Processing field: cyc0000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0000\OCVdc.csv'
# Processing field: cyc0100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0100\OCVdc.csv'
# Processing field: cyc0200
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0200\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0200\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0200\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0200\OCVdc.csv'
# Processing field: cyc0300
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0300\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0300\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0300\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0300\OCVdc.csv'
# Processing field: cyc0400
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0400\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0400\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0400\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0400\OCVdc.csv'
# Processing field: cyc0500
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0500\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0500\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0500\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0500\OCVdc.csv'
# Processing field: cyc0600
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0600\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0600\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0600\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0600\OCVdc.csv'
# Processing field: cyc0700
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0700\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0700\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0700\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0700\OCVdc.csv'
# Processing field: cyc0800
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0800\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0800\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0800\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0800\OCVdc.csv'
# Processing field: cyc0900
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc0900\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc0900\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc0900\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc0900\OCVdc.csv'
# Processing field: cyc1000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc1000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc1000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc1000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc1000\OCVdc.csv'
# Processing field: cyc1100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc1100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc1100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc1100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc1100\OCVdc.csv'
# Processing field: cyc1200
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc1200\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc1200\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc1200\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc1200\OCVdc.csv'
# Processing field: cyc1300
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc1300\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc1300\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc1300\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc1300\OCVdc.csv'
# Processing field: cyc1400
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc1400\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc1400\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc1400\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc1400\OCVdc.csv'
# Processing field: cyc1600
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc1600\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc1600\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc1600\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc1600\OCVdc.csv'
# Processing field: cyc1800
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc1800\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc1800\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc1800\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc1800\OCVdc.csv'
# Processing field: cyc1900
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc1900\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc1900\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc1900\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc1900\OCVdc.csv'
# Processing field: cyc2000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2000\OCVdc.csv'
# Processing field: cyc2100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2100\OCVdc.csv'
# Processing field: cyc2200
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2200\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2200\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2200\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2200\OCVdc.csv'
# Processing field: cyc2300
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2300\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2300\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2300\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2300\OCVdc.csv'
# Processing field: cyc2400
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2400\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2400\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2400\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2400\OCVdc.csv'
# Processing field: cyc2500
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2500\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2500\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2500\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2500\OCVdc.csv'
# Processing field: cyc2600
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2600\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2600\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2600\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2600\OCVdc.csv'
# Processing field: cyc2700
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2700\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2700\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2700\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2700\OCVdc.csv'
# Processing field: cyc2800
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2800\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2800\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2800\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2800\OCVdc.csv'
# Processing field: cyc2900
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc2900\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc2900\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc2900\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc2900\OCVdc.csv'
# Processing field: cyc3000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc3000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc3000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc3000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc3000\OCVdc.csv'
# Processing field: cyc3100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc3100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc3100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc3100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc3100\OCVdc.csv'
# Processing field: cyc3200
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc3200\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc3200\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc3200\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc3200\OCVdc.csv'
# Processing field: cyc3300
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc3300\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc3300\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc3300\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc3300\OCVdc.csv'
# Processing field: cyc3500
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc3500\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc3500\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc3500\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc3500\OCVdc.csv'
# Processing field: cyc3600
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc3600\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc3600\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc3600\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc3600\OCVdc.csv'
# Processing field: cyc3700
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc3700\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc3700\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc3700\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc3700\OCVdc.csv'
# Processing field: cyc3800
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc3800\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc3800\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc3800\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc3800\OCVdc.csv'
# Processing field: cyc3900
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc3900\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc3900\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc3900\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc3900\OCVdc.csv'
# Processing field: cyc4000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc4000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc4000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc4000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc4000\OCVdc.csv'
# Processing field: cyc4100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell2\cyc4100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell2\cyc4100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell2\cyc4100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell2\cyc4100\OCVdc.csv'
# Processing field: cyc4200
# ...
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc3900\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc3900\OCVdc.csv'
# Processing field: cyc4000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc4000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc4000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc4000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc4000\OCVdc.csv'
# Processing field: cyc4100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc4100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc4100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc4100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc4100\OCVdc.csv'
# Processing field: cyc4200
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc4200\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc4200\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc4200\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc4200\OCVdc.csv'
# Processing field: cyc4300
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc4300\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc4300\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc4300\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc4300\OCVdc.csv'
# Processing field: cyc4400
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc4400\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc4400\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc4400\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc4400\OCVdc.csv'
# Processing field: cyc4500
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc4500\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc4500\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc4500\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc4500\OCVdc.csv'
# Processing field: cyc4600
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc4600\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc4600\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc4600\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc4600\OCVdc.csv'
# Processing field: cyc4800
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc4800\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc4800\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc4800\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc4800\OCVdc.csv'
# Processing field: cyc5000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5000\OCVdc.csv'
# Processing field: cyc5100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5100\OCVdc.csv'
# Processing field: cyc5200
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5200\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5200\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5200\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5200\OCVdc.csv'
# Processing field: cyc5300
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5300\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5300\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5300\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5300\OCVdc.csv'
# Processing field: cyc5400
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5400\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5400\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5400\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5400\OCVdc.csv'
# Processing field: cyc5500
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5500\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5500\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5500\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5500\OCVdc.csv'
# Processing field: cyc5600
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5600\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5600\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5600\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5600\OCVdc.csv'
# Processing field: cyc5700
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5700\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5700\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5700\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5700\OCVdc.csv'
# Processing field: cyc5800
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5800\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5800\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5800\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5800\OCVdc.csv'
# Processing field: cyc5900
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc5900\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc5900\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc5900\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc5900\OCVdc.csv'
# Processing field: cyc6000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6000\OCVdc.csv'
# Processing field: cyc6100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6100\OCVdc.csv'
# Processing field: cyc6200
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6200\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6200\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6200\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6200\OCVdc.csv'
# Processing field: cyc6300
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6300\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6300\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6300\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6300\OCVdc.csv'
# Processing field: cyc6400
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6400\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6400\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6400\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6400\OCVdc.csv'
# Processing field: cyc6500
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6500\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6500\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6500\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6500\OCVdc.csv'
# Processing field: cyc6600
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6600\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6600\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6600\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6600\OCVdc.csv'
# Processing field: cyc6700
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6700\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6700\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6700\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6700\OCVdc.csv'
# Processing field: cyc6800
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6800\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6800\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6800\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6800\OCVdc.csv'
# Processing field: cyc6900
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc6900\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc6900\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc6900\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc6900\OCVdc.csv'
# Processing field: cyc7000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7000\OCVdc.csv'
# Processing field: cyc7100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7100\OCVdc.csv'
# Processing field: cyc7200
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7200\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7200\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7200\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7200\OCVdc.csv'
# Processing field: cyc7300
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7300\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7300\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7300\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7300\OCVdc.csv'
# Processing field: cyc7400
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7400\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7400\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7400\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7400\OCVdc.csv'
# Processing field: cyc7500
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7500\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7500\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7500\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7500\OCVdc.csv'
# Processing field: cyc7600
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7600\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7600\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7600\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7600\OCVdc.csv'
# Processing field: cyc7700
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7700\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7700\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7700\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7700\OCVdc.csv'
# Processing field: cyc7800
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7800\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7800\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7800\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7800\OCVdc.csv'
# Processing field: cyc7900
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc7900\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc7900\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc7900\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc7900\OCVdc.csv'
# Processing field: cyc8000
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc8000\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc8000\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc8000\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc8000\OCVdc.csv'
# Processing field: cyc8100
# Sub-fields in element: ('C1ch', 'C1dc', 'OCVch', 'OCVdc')
# Processing sub-field: C1ch
# C1ch data saved to 'data\Cell8\cyc8100\C1ch.csv'
# Processing sub-field: C1dc
# C1dc data saved to 'data\Cell8\cyc8100\C1dc.csv'
# Processing sub-field: OCVch
# OCVch data saved to 'data\Cell8\cyc8100\OCVch.csv'
# Processing sub-field: OCVdc
# OCVdc data saved to 'data\Cell8\cyc8100\OCVdc.csv'
# Data extraction and saving complete.
